# %% [markdown]
# # Storytelling Case Study: Airbnb, NYC

# %% [markdown]
# **Problem background**:
# Suppose that you are working as a data analyst at Airbnb. For the past few months, Airbnb has seen a major decline in revenue. Now that the restrictions have started lifting and people have started to travel more, Airbnb wants to make sure that it is fully prepared for this change.
#
#
#
# The different leaders at Airbnb want to understand some important insights based on various attributes in the dataset so as to increase the revenue such as -
#
# - Which type of hosts to acquire more and where?
# - The categorisation of customers based on their preferences.
# - What are the neighbourhoods they need to target?
# - What is the pricing ranges preferred by customers?
# - The various kinds of properties that exist w.r.t. customer preferences.
# - Adjustments in the existing properties to make it more customer-oriented.
# - What are the most popular localities and properties in New York currently?
# - How to get unpopular properties more traction? and so on...
#
#
# - *Note: These points are just to give you an initial understanding of how to proceed with the analysis and the kind of questions you need to ask. In addition to this, you would need to further understand the data (attached below in this page) and analyse important insights that you feel are required for the audiences mentioned for each of the two presentations.*

# %% [markdown]
# **End Objective**:
#
# To prepare for the next best steps that Airbnb needs to take as a business, you have been asked to analyse a dataset consisting of various Airbnb listings in New York. Based on this analysis, you need to give two presentations to the following groups.
#
# 1. Presentation - I
#  - Data Analysis Managers: These people manage the data analysts directly for processes and their technical expertise is basic.
#  - Lead Data Analyst: The lead data analyst looks after the entire team of data and business analysts and is technically sound.
#
# 2. Presentation - II
#  - Head of Acquisitions and Operations, NYC: This head looks after all the property and host acquisitions and operations. Acquisition of the best properties, price negotiation, and negotiating the services the properties offer falls under the purview of this role.
#  - Head of User Experience, NYC: The head of user experience looks after the customer preferences and also handles the properties listed on the website and the Airbnb app. Basically, the head of user experience tries to optimise the order of property listing in certain neighbourhoods and cities in order to get every property the optimal amount of traction.

# %% [markdown]
# #### Import Liabraries

# %%
# Import Liabraries
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
import geopandas as gpd
from shapely.geometry import Point
import warnings
warnings.filterwarnings ('ignore')

# %% [markdown]
# **Data Dictionary**:
#
# This dataset contains information about different Airbnb listings along with their hosts, locations, prices and other attributes.

# %%
Data_Dictionary = pd.read_excel('Data_Dictionary.xlsx')
Data_Dictionary
# Out:
#                             Column  \
# 0                               id
# 1                             name
# 2                          host_id
# 3                        host_name
# 4              neighbourhood_group
# 5                    neighbourhood
# 6                         latitude
# 7                        longitude
# 8                        room_type
# 9                            price
# 10                  minimum_nights
# 11               number_of_reviews
# 12                     last_review
# 13               reviews_per_month
# 14  calculated_host_listings_count
# 15                availability_365
#
#                                           Description
# 0                                          listing ID
# 1                                 name of the listing
# 2                                             host ID
# 3                                    name of the host
# 4                                            location
# 5                                                area
# 6                                latitude coordinates
# 7                               longitude coordinates
# 8                                  listing space type
# 9                                               price
# 10                           amount of nights minimum
# 11                                  number of reviews
# 12                                      latest review
# 13                        number of reviews per month
# 14                         amount of listing per host
# 15  number of days when listing is available for b...

# %% [markdown]
# #### Variables into different types:

# %% [markdown]
# You can classify the variables into different types – categorical, numeric, location and time. It is important to understand which plot needs to be used for plotting each variable. You can refer to the variable categories by looking at the diagram given below.

# %% [markdown]
# #### Submissions required:
#
# - PPT-I: A presentation with 8-12 slides to be showcased to the data analysis managers and lead data analyst in PDF format.
# - PPT-II: A presentation with 8-12 slides to be showcased to the Head of Acquisitions & Operations and the Head of User Experience in PDF format.
# - Methodology Document: A document attached in the appendix of both the presentations that showcase the methodology that was undertaken for the analysis along with all the steps/codes that were performed in detail (You can find more details in the evaluation rubric segment). Without this document, the other parts of your case study will not be evaluated and you will be rewarded zero marks for the assignment.

# %% [markdown]
# Some tips before starting the case study
# Please go through all of the points mentioned below carefully.
#
# 1. The case study has been kept deliberately vague with little background information. So don't get worried and make sure you perform a thorough analysis of the data and extract the most meaningful insights.
# 2. Many a time you do get such loosely presented business problems where you don't have much business background. In such cases, it is important to stick to the basics and perform all data cleaning, analysis and visualisation processes structurally.
# 3. This assignment is different from the ones you have solved before. Make sure that you treat this case study as a storytelling exercise and not an analysis/visualisation one. This will help you be better prepared for the presentations.
# 4. Although this is a storytelling exercise meaning that the tasks performed on the data are not important for the end objective, there is a methodology document that you need to submit. This document should ideally contain the entire methodology, technical details, and assumptions wherever applicable. This document is also necessary to verify all the steps you have performed to arrive at the final presentations and hence without it, your presentations will not be graded.
# 5. The data cleaning, analysis, and visualisation part can be done on any tool(s) of your choice. But again, make sure that you are documenting all the steps, assumptions, and major codes/plots.
# 6. Once you are done with the analysis and visualisations, there will be many insights at your hand. Make sure that you map the right visuals and takeaways with the right audience since some of these insights might be relevant to one group but not to the other group.
# 7. Recall all the elements mentioned by Utkalika and always try to follow the rules to tell a good data story while creating the presentation.
# 8. Most importantly, have fun solving this case study!

# %% [markdown]
# #### Import dataset

# %%
# Import datase

df =pd.read_csv('AB_NYC_2019.csv')
df.head(3)
# Out:
#          id                                               name  host_id  \
# 0  23669201  Great Price: Williamsburg Brooklyn Loft off L ...     2438
# 1   1101224                                         THE PUTNAM     2571
# 2      2539                 Clean & quiet apt home by the park     2787
#
#   host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Tasos            Brooklyn        Williamsburg  40.71412  -73.94447
# 1     Teedo            Brooklyn  Bedford-Stuyvesant  40.68674  -73.93845
# 2      John            Brooklyn          Kensington  40.64749  -73.97237
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt     95              45                  1  17-03-2018
# 1  Entire home/apt    182               9                 27  21-05-2019
# 2     Private room    149               1                  9  19-10-2018
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.06                               1                 0
# 1               0.37                               1                23
# 2               0.21                               6               365

# %%
# Checking shape of df

df.shape
# Out:
# (48895, 16)

# %%
# Checking data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
#  12  last_review                     38843 non-null  object
#  13  reviews_per_month               38843 non-null  float64
#  14  calculated_host_listings_count  48895 non-null  int64
#  15  availability_365                48895 non-null  int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 6.0+ MB

# %%
# Checking basic statistic
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# min          1.000000           0.000000           0.010000
# 25%          1.000000           1.000000           0.190000
# 50%          3.000000           5.000000           0.720000
# 75%          5.000000          24.000000           2.020000
# max       1250.000000         629.000000          58.500000
#
#        calculated_host_listings_count  availability_365
# count                    48895.000000      48895.000000
# mean                         7.143982        112.781327
# std                         32.952519        131.622289
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         45.000000
# 75%                          2.000000        227.000000
# max                        327.000000        365.000000

# %%
# Checking null values

df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Checking null values in %

round(df.isnull().sum()/len(df)*100,2)
# Out:
# id                                 0.00
# name                               0.03
# host_id                            0.00
# host_name                          0.04
# neighbourhood_group                0.00
# neighbourhood                      0.00
# latitude                           0.00
# longitude                          0.00
# room_type                          0.00
# price                              0.00
# minimum_nights                     0.00
# number_of_reviews                  0.00
# last_review                       20.56
# reviews_per_month                 20.56
# calculated_host_listings_count     0.00
# availability_365                   0.00
# dtype: float64

# %%
# Unique Host

df.host_id.nunique()
# Out:
# 37457

# %%
# Find duplicates
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - No duplicate values in dataset

# %%
# Filled Null values as Unknown
df[['name', 'host_name']]= df[['name', 'host_name']].fillna('Unknown')

# %%
# Filled Null values as 0 >> Because number_of_reviews column having 0 value, so reviews_per_month will be 0.
df['reviews_per_month']= df['reviews_per_month'].fillna(0)

# %%
# Changing data format to date
df['last_review'] = pd.to_datetime(df['last_review'])

# %%
# Checking Dtype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48895 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48895 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
#  12  last_review                     38843 non-null  datetime64[ns]
#  13  reviews_per_month               48895 non-null  float64
#  14  calculated_host_listings_count  48895 non-null  int64
#  15  availability_365                48895 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(7), object(5)
# memory usage: 6.0+ MB

# %%
# Checking above changes
df [df['name']== 'Unknown'].head()
# Out:
#             id     name   host_id host_name neighbourhood_group  \
# 4594   4756856  Unknown   1832442  Carolina            Brooklyn
# 11064  1615764  Unknown   6676776     Peter           Manhattan
# 15139  2232600  Unknown  11395220      Anna           Manhattan
# 20128  4209595  Unknown  20700823     Jesse           Manhattan
# 20555  4581788  Unknown  21600904     Lucie            Brooklyn
#
#            neighbourhood  latitude  longitude        room_type  price  \
# 4594            Bushwick  40.70046  -73.92825     Private room     70
# 11064  Battery Park City  40.71239  -74.01620  Entire home/apt    400
# 15139       East Village  40.73215  -73.98821  Entire home/apt    200
# 20128  Greenwich Village  40.73473  -73.99244  Entire home/apt    225
# 20555       Williamsburg  40.71370  -73.94378     Private room    150
#
#        minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 4594                1                  0         NaT               0.00
# 11064            1000                  0         NaT               0.00
# 15139               1                 28  2015-06-08               0.45
# 20128               1                  1  2015-01-01               0.02
# 20555               1                  0         NaT               0.00
#
#        calculated_host_listings_count  availability_365
# 4594                                1                 0
# 11064                               1               362
# 15139                               1               341
# 20128                               1                 0
# 20555                               1                 0

# %%
df.isna().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Checking neighbourhood_group values
df.neighbourhood_group.value_counts()
# Out:
# neighbourhood_group
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: count, dtype: int64

# %%
# Checking neighbourhood values
df.neighbourhood.value_counts()
# Out:
# neighbourhood
# Williamsburg          3920
# Bedford-Stuyvesant    3714
# Harlem                2658
# Bushwick              2465
# Upper West Side       1971
#                       ...
# Richmondtown             1
# Rossville                1
# Woodrow                  1
# New Dorp                 1
# Willowbrook              1
# Name: count, Length: 221, dtype: int64

# %%
# room_type
df.room_type.value_counts()
# Out:
# room_type
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: count, dtype: int64

# %%
# Price values
df.price.plot.box()
# Out:
# <Axes: >

# %%
df.minimum_nights.value_counts()
# Out:
# minimum_nights
# 1      12720
# 2      11696
# 3       7999
# 30      3760
# 4       3303
#        ...
# 43         1
# 114        1
# 250        1
# 400        1
# 182        1
# Name: count, Length: 109, dtype: int64

# %%
df.minimum_nights.plot.box()
# Out:
# <Axes: >

# %%
# Capping at 500

df['minimum_nights']= df['minimum_nights'].where(df['minimum_nights']<500,500)
df.minimum_nights.plot.box()
# Out:
# <Axes: >

# %%
df.number_of_reviews.plot.box()
# Out:
# <Axes: >

# %%
df.number_of_reviews.median()
# Out:
# 5.0

# %%
df.number_of_reviews.mean()
# Out:
# 23.274465691788528

# %%
# 
df.calculated_host_listings_count.plot.box()
# Out:
# <Axes: >

# %%
df.availability_365.plot.box()
# Out:
# <Axes: >

# %%
# Dropping Unnecessary columns
df = df.drop (['last_review', 'id' ], axis=1)

# %%
# Adding Column with Low review (0)
df['Low_review'] = df['number_of_reviews']==0
df['Low_review_01'] = (df['number_of_reviews']==0).astype(int)

# %%
# Export dataframe to .csv

df.to_csv('Airbnb_NYC_final.csv')

# %%
df.head()
# Out:
#                                                 name  host_id host_name  \
# 0  Great Price: Williamsburg Brooklyn Loft off L ...     2438     Tasos
# 1                                         THE PUTNAM     2571     Teedo
# 2                 Clean & quiet apt home by the park     2787      John
# 3  Riomaggiore Room. Queen Bedroom in Bklyn Townh...     2787      John
# 4                               Torre del Lago Room.     2787      John
#
#   neighbourhood_group       neighbourhood  latitude  longitude  \
# 0            Brooklyn        Williamsburg  40.71412  -73.94447
# 1            Brooklyn  Bedford-Stuyvesant  40.68674  -73.93845
# 2            Brooklyn          Kensington  40.64749  -73.97237
# 3            Brooklyn         Bensonhurst  40.60951  -73.97622
# 4            Brooklyn           Gravesend  40.60755  -73.97410
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0  Entire home/apt     95              45                  1
# 1  Entire home/apt    182               9                 27
# 2     Private room    149               1                  9
# 3     Private room     99               1                 21
# 4     Private room     79               1                 17
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.06                               1                 0
# 1               0.37                               1                23
# 2               0.21                               6               365
# 3               0.50                               6               153
# 4               0.40                               6               174
#
#    Low_review  Low_review_01
# 0       False              0
# 1       False              0
# 2       False              0
# 3       False              0
# 4       False              0

# %%
# Correlation matrix

df_num = df[['price', 'minimum_nights',
           'number_of_reviews', 'reviews_per_month',
           'calculated_host_listings_count', 'availability_365']]
corr_metrix= df_num.corr()



plt.figure(figsize=(8,6))
sns.heatmap(corr_metrix, annot=True, cmap='Greens')
plt.title('Correlation Matrix')
plt.show()

# %%
df.columns
# Out:
# Index(['name', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood',
#        'latitude', 'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365', 'Low_review',
#        'Low_review_01'],
#       dtype='object')

# %%
# Create a GeoDataFrame from csv (lat long to point)
nyc_zip = [Point(xy) for xy in zip(df['longitude'], df['latitude'])]
nyc_point = gpd.GeoDataFrame(df, geometry=nyc_zip)
nyc_point.plot()
# Out:
# <Axes: >

# %%
# Loaded a NYC map shapefile
nyc_area = gpd.read_file('NYC_Boundary.shp')

ax = nyc_area.plot(figsize=(8, 7), color='lightgrey', edgecolor='black')

# Overlay points on top of the polygons
nyc_point.plot(ax=ax, color='red', markersize=5, alpha=0.6)
plt.title('NYC All Listings')
plt.show()

# %%
#Number of Days Booking Available
fig,ax = plt.subplots(figsize=(12,12))
nyc_area.plot(ax=ax,alpha=0.8,edgecolor='black',color='lightblue')
nyc_point.plot(column='availability_365',ax=ax,legend=True,cmap='plasma',markersize=3)

plt.title("Number of Days Booking Available")
plt.axis('off')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 12))

# Plot the NYC area polygons with a base color
nyc_area.plot(ax=ax, color='lightgrey', edgecolor='black')  # Base color for NYC area

# Plot the points, adjusting the colormap and setting custom color scale limits
# Set vmin and vmax to control the color mapping and emphasize high-price areas
nyc_point.plot(column='price', ax=ax, legend=True, cmap='YlOrRd', markersize=3, vmin=10, vmax=500)

# Title and other plot settings
plt.title("Price Distribution of Airbnb Listings in NYC")
plt.axis('off')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 12))

# Plot the NYC area polygons with a base color
nyc_area.plot(ax=ax, color='lightgrey', edgecolor='black')  # Base color for NYC area

# Plot the points, adjusting the colormap and setting custom color scale limits
# Set vmin and vmax to control the color mapping and emphasize high-price areas
nyc_point.plot(column='Low_review_01', ax=ax, legend=True, cmap='YlOrRd', markersize=3, vmin=0, vmax=1)

# Title and other plot settings
plt.title("Low Rating in NYC")
plt.axis('off')
plt.show()

# %%
#Number of Days Booking Available
fig,ax = plt.subplots(figsize=(12,12))
nyc_area.plot(ax=ax,alpha=0.8,edgecolor='black',color='lightblue')
nyc_point.plot(column='number_of_reviews',ax=ax,legend=True,cmap='plasma',markersize=3, vmin=0, vmax=20)

plt.title("Number of Reviews")
plt.axis('off')
plt.show()

# %%
df.number_of_reviews.plot.box()
# Out:
# <Axes: >

# %%
df.head()
# Out:
#                                                 name  host_id host_name  \
# 0  Great Price: Williamsburg Brooklyn Loft off L ...     2438     Tasos
# 1                                         THE PUTNAM     2571     Teedo
# 2                 Clean & quiet apt home by the park     2787      John
# 3  Riomaggiore Room. Queen Bedroom in Bklyn Townh...     2787      John
# 4                               Torre del Lago Room.     2787      John
#
#   neighbourhood_group       neighbourhood  latitude  longitude  \
# 0            Brooklyn        Williamsburg  40.71412  -73.94447
# 1            Brooklyn  Bedford-Stuyvesant  40.68674  -73.93845
# 2            Brooklyn          Kensington  40.64749  -73.97237
# 3            Brooklyn         Bensonhurst  40.60951  -73.97622
# 4            Brooklyn           Gravesend  40.60755  -73.97410
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0  Entire home/apt     95              45                  1
# 1  Entire home/apt    182               9                 27
# 2     Private room    149               1                  9
# 3     Private room     99               1                 21
# 4     Private room     79               1                 17
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.06                               1                 0
# 1               0.37                               1                23
# 2               0.21                               6               365
# 3               0.50                               6               153
# 4               0.40                               6               174
#
#    Low_review  Low_review_01
# 0       False              0
# 1       False              0
# 2       False              0
# 3       False              0
# 4       False              0
